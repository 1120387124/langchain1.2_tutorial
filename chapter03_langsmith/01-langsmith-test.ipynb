# %%
import os

from dotenv import load_dotenv

#刷新环境变量


load_dotenv(override=False)

# 获取单个环境变量
path = os.environ.get('LANGSMITH_API_KEY')
print(path)
path = os.environ.get('DEEPSEEK_API_KEY')
print(path)

# %% [markdown]
# 案例1

# %%
import os
from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 将env文件中的变量加载为环境变量
#override=True：表示.env优先
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

model = ChatDeepSeek(
    api_key=DEEPSEEK_API_KEY,
    model_name="deepseek-v4-flash"
)
print(model.invoke("你好"))
# Out:
# content='你好！很高兴见到你🙌\n\n今天有什么我可以帮你的吗？无论是聊聊日常、讨论问题，还是需要一些建议，我都在这里。比如，想聊聊时下的新闻、分享一个有趣的想法，或者单纯想吐槽一下天气？😄' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户发来一句简单的“你好”。这是一个非常基础的问候，没有具体的指令或问题。用户可能是在测试连接，或者只是开启一次对话。深层需求可能是想要一个友好、热情的回应，以确认我能够正常交流，并表达愿意提供帮助的态度。\n\n想到了用同样温暖亲切的问候来回应，并主动打开对话，邀请用户提出具体需求。可以用开放式的问句，比如询问今天有什么可以帮忙的，或者聊聊天气、日常等轻松话题，这样既回应了问候，又为后续互动创造了空间。'} response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 5, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 114, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '77d0a63c-998e-48ce-9cd5-91f901946154', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f46c4-6112-7e42-b39c-762d7b9e7759-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 168, 'total_tokens': 173, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 114}}

# %% [markdown]
# 案例2

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
model = init_chat_model(model="deepseek-v4-flash",
                        model_provider="deepseek",
                        api_key=DEEPSEEK_API_KEY,
                        base_url='https://api.deepseek.com')
print(model.invoke("你好，用一句话回答"))
# Out:
# content='在的，请问有什么可以帮您？' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我用一句话回答，但没有具体问题。这可能是想测试我能否简洁回应，或者ta暂时没想好问什么。既然要求“一句话”，我需要主动提供帮助方向。直接说“请提出具体问题”太生硬，可以表达随时可服务的意愿，同时保持一句话的完整性。想到了用“在的”、“请问”开头，再表明愿意协助的语气，这样既符合格式又显得友好。'} response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 9, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 90, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'd17ea41b-b54f-4e63-8373-55fbf2e8e6fa', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f46c7-5838-7621-8875-80b35193c066-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 100, 'total_tokens': 109, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 90}}

# %%
案例3

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
from rich import print as rprint

# 从.env文件中加载环境变量
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
# 1. 初始化模型
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0.2,
    max_tokens=500,
    # 指定可调整参数
    configurable_fields=("model", "model_provider", "temperature",
                         "max_tokens"),
)
# 2. 准备 config 字典
config = {
    "run_name": "joke_generation",  # 在LangSmith中这次运行会显示为
    "joke_generation"
    "tags": ["my_tag1", "my_tag2"],  # 打上标签便于分类查找
    "metadata": {
        "user_id": "shkstart",
        # 记录用户ID
        "session_id": "sess_123"  # 记录会话ID
    },
    "configurable": {
        "model": "deepseek-v4-pro",  # 配置模型参数
        "model_provider": "openai",  # 配置模型提供商参数
        "temperature": 0.7,  # 配置温度参数
        "max_tokens": 1000  # 配置最大令牌数
    }
}
# 3. 调用模型并传入config
response = model.invoke(
    "1 + 2 = ？",
    config=config
)
rprint(response)
# Out:
# AIMessage(
#     content='1 + 2 = 3',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 52,
#             'prompt_tokens': 11,
#             'total_tokens': 63,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 44,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 11
#         },
#         'model_provider': 'openai',
#         'model_name': 'deepseek-v4-pro',
#         'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402',
#         'id': 'bcdf95fe-e1d0-4c5f-8c4a-0a1eff276f2d',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f46cf-3f10-7851-94e8-352be06caa73-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 11,
#         'output_tokens': 52,
#         'total_tokens': 63,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 44}
#     }
# )
