# %% [markdown]
# ![image.png](attachment:d3ad047e-9f9c-4d0c-b1bd-066e3acd46a4.png)

# %% [markdown]
# ![image.png](attachment:899980dd-ea16-43bc-80ab-d3389ba12981.png)
# ![image.png](attachment:5575eacd-cfa1-46f8-bf65-1deb69180fc9.png)
